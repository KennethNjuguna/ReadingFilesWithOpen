# %% [markdown]
# # <h3> Loading the correct Libraries below. </h3>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # <h4> We declare the headers of the dataset below. </h4>

# %%
headers =["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","wheel-base",
          "length","width","height","curb-weight","engine-type","num-of-cylinders","engine-size","fuel-system","bore","stroke","compress","stroke","compress",
          "horse-power","peak-rpm","city-mpg","highway-mpg","price"]

# %% [markdown]
# # <h4>We use the method "read-csv()" to load the dataset Automobile below </h4>

# %%
df= pd.read_csv ("Automobile_data.csv")

# %% [markdown]
# # <h4> We use the method "head()" to read the first five rows of the dataset </h4>

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors
# 0          3             122.0  alfa-romero       gas        std          two  \
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 0  convertible          rwd           front        88.6  ...          130  \
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# # <h4> As observed above we have so many "?" meaning there is a lot of missing data in the dataset which needs to be replace. </h4>

# %% [markdown]
# # <h4> We use the method "tail()" to read the last five rows of the dataset. </h4>

# %%
df.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors
# 200         -1                95  volvo       gas        std         four  \
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 200      sedan          rwd           front       109.1  ...          141  \
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm
# ...

# %% [markdown]
# # <h5>Steps of dealing with missing data </h5>
# <p>Identify the missing data.</p>
# <p>Correct the missing data.</p>
# <p>Correct data format</p>

# %% [markdown]
# # <h4> Replacing the "?" with NaN- Not A Number </h4>

# %%
import numpy as np

#Replace the "?" with NaN
df.replace("?", np.nan, inplace=True)

# %% [markdown]
# # <h4>Check for the Missing values "?" have being replaced using the head() method</h4>

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors
# 0          3             122.0  alfa-romero       gas        std          two  \
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 0  convertible          rwd           front        88.6  ...          130  \
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# # <h4>Evaluating missing data. </h4>
# # <h4>There are two ways to identify missing values.</h4>
# # <h5> 1. .isnull() </h5>
# # <h5> 2. .notnull() </h5>

# %%
missing_data =df.isnull()
missing_data.head(5)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors
# 0      False              False  False      False       False         False  \
# 1      False              False  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size
# 0       False         False            False       False  ...        False  \
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %% [markdown]
# # <h5> "True" means the value is missing value while "False" missing there is no missing value. </h5>

# %% [markdown]
# # <h3>Count missing values in each column.</h3>
# # <h6>We will use a loop in Python to finally figure it out the number of missing values in each column. As mentioned "True" means there is missing value while "False" means there is no missing values within that column. </h6>

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# symboling
# symboling
# False    205
# Name: count, dtype: int64
#
# normalized-losses
# normalized-losses
# False    205
# Name: count, dtype: int64
#
# make
# make
# False    205
# Name: count, dtype: int64
#
# fuel-type
# fuel-type
# False    205
# Name: count, dtype: int64
#
# aspiration
# aspiration
# False    205
# Name: count, dtype: int64
#
# num-of-doors
# num-of-doors
# False    203
# True       2
# Name: count, dtype: int64
#
# body-style
# body-style
# False    205
# Name: count, dtype: int64
#
# drive-wheels
# drive-wheels
# False    205
# Name: count, dtype: int64
#
# engine-location
# engine-location
# False    205
# Name: count, dtype: int64
#
# wheel-base
# wheel-base
# False    205
# Name: count, dtype: int64
#
# length
# length
# False    205
# Name: count, dtype: int64
#
# width
# width
# False    205
# Name: count, dtype: int64
#
# height
# height
# False    205
# Name: count, dtype: int64
#
# curb-weight
# curb-weight
# False    205
# Name: count, dtype: int64
# ...

# %% [markdown]
# # <h4> Calculate the mean value for the "Normalized losses" in the column </h4>

# %%
avg_norm_loss = df["normalized-losses"].astype("float").mean(axis=0)
print("Average Normalized losses", avg_norm_loss)
# Out:
# Average Normalized losses 122.0

# %% [markdown]
# # <h4> Replace the NaN value with mean in Normalized losses. </h4>

# %%
df["normalized-losses"].replace(np.nan, avg_norm_loss, inplace=True)

# %% [markdown]
# # <h4>Calculate the mean value for the "bore" in the column.</h4>

# %%
bore_avg = df["bore"].astype("float").mean(axis=0)
print("Average Bore", bore_avg)
# Out:
# Average Bore 3.3297512437810943

# %% [markdown]
# # <h4> Replace the NaN value with mean in Bore. </h4>

# %%
df["bore"].replace(np.nan, bore_avg, inplace=True)

# %% [markdown]
# # <h3>Replace the NaN value with mean in Stroke Column. We start by calculate the average of the stroke column</h3>

# %%
strokeAvg= df["stroke"].astype("float").mean(axis=0)
print("Average Stroke", strokeAvg)
# Out:
# Average Stroke 3.255422885572139

# %% [markdown]
# # <h4>Now, replace the NaN value with the mean. </h4>

# %%
df["stroke"].replace(np.nan,strokeAvg,inplace=True)

# %% [markdown]
# # <h4> Calculating the mean value of the Horsepower column in the dataset. </h4>

# %%
horsepowerAvg= df["horsepower"].astype("float").mean(axis=0)
print("Average Horsepower", horsepowerAvg)
# Out:
# Average Horsepower 104.25615763546799

# %% [markdown]
# # <h3> Replace the NaN Value in the horsepower column with the mean value. </h4>

# %%
df["horsepower"].replace(np.nan,horsepowerAvg,inplace=True)

# %% [markdown]
# # <h4>Calculate the mean Value of Peak Rpm column </h4>

# %%
PeakRpmAvg= df["peak-rpm"].astype("float").mean(axis=0)
print("Average of Rpm",PeakRpmAvg)
# Out:
# Average of Rpm 5125.369458128079

# %% [markdown]
# # <h4> Replace NaN values of peak rpm with mean value. </h4>

# %%
df["peak-rpm"].replace(np.nan,PeakRpmAvg,inplace=True)

# %% [markdown]
# # <h4> To check the most common values in a column we can use the value_counts() method. </h4>

# %% [markdown]
# # <h4>Below we check the most common values in the column Num of Doors. </h4>

# %%
df["num-of-doors"].value_counts()
# Out:
# num-of-doors
# four    114
# two      89
# Name: count, dtype: int64

# %% [markdown]
# # <h4>.idxmax method gets the most common value automatically. </h4>
